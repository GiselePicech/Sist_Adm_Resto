# %%
from tkinter import *
from tkinter import ttk

# %%
ventana = Tk()
ventana.title('Sistema Administracion Resto PM')
ventana.geometry('1260x650')
ventana.resizable(0,0)
ventana.config(bg='darkblue')

##Fuentes
Title = ('arial black',25)
Subtitle = ('consolas', 14)

##Marco de titulo principal
marcoSuperior = Frame(ventana, bd=12, relief=RIDGE, bg='blue')
marcoSuperior.pack(side=TOP)

##Titulo principal
tituloPrincipal = Label(marcoSuperior, text='Sistema Administracion Resto PM', font=Title, fg='white', bg='blue', width=54)
tituloPrincipal.grid(row=0,column=0)

#marcos secundarios
marcoMenu = Frame(ventana, bd=10, relief=RIDGE, bg='blue')
marcoMenu.pack(side=LEFT)
marcoCosto = Frame(marcoMenu, bd=2, relief=RIDGE, bg='blue')
marcoCosto.pack(side=BOTTOM)
marcoComidas = LabelFrame(marcoMenu, text='Platos', bd=5, font=Subtitle, relief=RIDGE, bg='lightgray')
marcoComidas.pack(side=LEFT)
marcoBebidas = LabelFrame(marcoMenu, text='Bebidas', bd=5, font=Subtitle, relief=RIDGE, bg='lightgray')
marcoBebidas.pack(side=LEFT)
marcoPostres = LabelFrame(marcoMenu, text='Postres', bd=5, font=Subtitle, relief=RIDGE, bg='lightgray')
marcoPostres.pack(side=LEFT)

#marcos derechos
marcoDerecho = Frame(ventana, bd=10, relief=RIDGE, bg='blue')
marcoDerecho.pack(side=RIGHT)
marcoCalculadora = Frame(marcoDerecho, bd=5, relief=RIDGE, bg='blue')
marcoCalculadora.pack()
marcoRecibo = Frame(marcoDerecho, bd=5, relief=RIDGE, bg='blue')
marcoRecibo.pack()
marcoBotones = Frame(marcoDerecho, bd=5, relief=RIDGE, bg='blue')
marcoBotones.pack()

#Comidas
#Etiqueta y boton para seleccionar
Pollo = Checkbutton(marcoComidas, text='Pollo',font=Subtitle, onvalue=1, offvalue=0).grid(row=0,column=0, sticky=W)
Ensalada = Checkbutton(marcoComidas, text='Ensalada',font=Subtitle, onvalue=1, offvalue=0).grid(row=1,column=0, sticky=W)
Arroz = Checkbutton(marcoComidas, text='Arroz',font=Subtitle, onvalue=1, offvalue=0).grid(row=2,column=0, sticky=W)
Pastas = Checkbutton(marcoComidas, text='Pastas',font=Subtitle, onvalue=1, offvalue=0).grid(row=3,column=0, sticky=W)
Carne = Checkbutton(marcoComidas, text='Carne',font=Subtitle, onvalue=1, offvalue=0).grid(row=4,column=0, sticky=W)
Pizza = Checkbutton(marcoComidas, text='Pizza',font=Subtitle, onvalue=1, offvalue=0).grid(row=5,column=0, sticky=W)
Mariscos = Checkbutton(marcoComidas, text='Mariscos',font=Subtitle, onvalue=1, offvalue=0).grid(row=6,column=0, sticky=W)
Tacos = Checkbutton(marcoComidas, text='Tacos',font=Subtitle, onvalue=1, offvalue=0).grid(row=7,column=0, sticky=W)
Paella = Checkbutton(marcoComidas, text='Paella',font=Subtitle, onvalue=1, offvalue=0).grid(row=8,column=0, sticky=W)
Lasagna = Checkbutton(marcoComidas, text='Lasagna',font=Subtitle, onvalue=1, offvalue=0).grid(row=9,column=0, sticky=W)
#Campo para completar
textPollo = Entry(marcoComidas, font=Subtitle, bd=7, width=8, state=DISABLED).grid(row=0,column=1)
textEnsalada = Entry(marcoComidas, font=Subtitle, bd=7, width=8, state=DISABLED).grid(row=1,column=1)
textArroz = Entry(marcoComidas, font=Subtitle, bd=7, width=8, state=DISABLED).grid(row=2,column=1)
textPastas = Entry(marcoComidas, font=Subtitle, bd=7, width=8, state=DISABLED).grid(row=3,column=1)
textCarne = Entry(marcoComidas, font=Subtitle, bd=7, width=8, state=DISABLED).grid(row=4,column=1)
textPizza = Entry(marcoComidas, font=Subtitle, bd=7, width=8, state=DISABLED).grid(row=5,column=1)
textMariscos = Entry(marcoComidas, font=Subtitle, bd=7, width=8, state=DISABLED).grid(row=6,column=1)
textTacos = Entry(marcoComidas, font=Subtitle, bd=7, width=8, state=DISABLED).grid(row=7,column=1)
textPaella = Entry(marcoComidas, font=Subtitle, bd=7, width=8, state=DISABLED).grid(row=8,column=1)
textLasagna = Entry(marcoComidas, font=Subtitle, bd=7, width=8, state=DISABLED).grid(row=9,column=1)

#Bebidas
#Etiqueta y boton para seleccionar
Agua = Checkbutton(marcoBebidas, text='Agua',font=Subtitle, onvalue=1, offvalue=0).grid(row=0,column=0, sticky=W)
Gaseosa = Checkbutton(marcoBebidas, text='Gaseosa',font=Subtitle, onvalue=1, offvalue=0).grid(row=1,column=0, sticky=W)
Vino = Checkbutton(marcoBebidas, text='Vino',font=Subtitle, onvalue=1, offvalue=0).grid(row=2,column=0, sticky=W)
Cerveza = Checkbutton(marcoBebidas, text='Cerveza',font=Subtitle, onvalue=1, offvalue=0).grid(row=3,column=0, sticky=W)
Champagne = Checkbutton(marcoBebidas, text='Champagne',font=Subtitle, onvalue=1, offvalue=0).grid(row=4,column=0, sticky=W)
Trago = Checkbutton(marcoBebidas, text='Trago',font=Subtitle, onvalue=1, offvalue=0).grid(row=5,column=0, sticky=W)
Licuado = Checkbutton(marcoBebidas, text='Licuado',font=Subtitle, onvalue=1, offvalue=0).grid(row=6,column=0, sticky=W)
Exprimido = Checkbutton(marcoBebidas, text='Exprimido',font=Subtitle, onvalue=1, offvalue=0).grid(row=7,column=0, sticky=W)
AguaSaborizada = Checkbutton(marcoBebidas, text='AguaSaborizada',font=Subtitle, onvalue=1, offvalue=0).grid(row=8,column=0, sticky=W)
AguaConGas = Checkbutton(marcoBebidas, text='AguaConGas',font=Subtitle, onvalue=1, offvalue=0).grid(row=9,column=0, sticky=W)
#Campo para completar
textAgua = Entry(marcoBebidas, font=Subtitle, bd=7, width=8, state=DISABLED).grid(row=0,column=1)
textGaseosa = Entry(marcoBebidas, font=Subtitle, bd=7, width=8, state=DISABLED).grid(row=1,column=1)
textVino = Entry(marcoBebidas, font=Subtitle, bd=7, width=8, state=DISABLED).grid(row=2,column=1)
textCerveza = Entry(marcoBebidas, font=Subtitle, bd=7, width=8, state=DISABLED).grid(row=3,column=1)
textChampagne = Entry(marcoBebidas, font=Subtitle, bd=7, width=8, state=DISABLED).grid(row=4,column=1)
textTrago = Entry(marcoBebidas, font=Subtitle, bd=7, width=8, state=DISABLED).grid(row=5,column=1)
textLicuado = Entry(marcoBebidas, font=Subtitle, bd=7, width=8, state=DISABLED).grid(row=6,column=1)
textExprimido = Entry(marcoBebidas, font=Subtitle, bd=7, width=8, state=DISABLED).grid(row=7,column=1)
textAguaSaborizada = Entry(marcoBebidas, font=Subtitle, bd=7, width=8, state=DISABLED).grid(row=8,column=1)
textAguaConGas = Entry(marcoBebidas, font=Subtitle, bd=7, width=8, state=DISABLED).grid(row=9,column=1)

#Postres
#Etiqueta y boton para seleccionar
Flan = Checkbutton(marcoPostres, text='Flan',font=Subtitle, onvalue=1, offvalue=0).grid(row=0,column=0, sticky=W)
DuraznosCrema = Checkbutton(marcoPostres, text='DuraznosCrema',font=Subtitle, onvalue=1, offvalue=0).grid(row=1,column=0, sticky=W)
FrutillasCrema = Checkbutton(marcoPostres, text='FrutillasCrema',font=Subtitle, onvalue=1, offvalue=0).grid(row=2,column=0, sticky=W)
LemonPie = Checkbutton(marcoPostres, text='LemonPie',font=Subtitle, onvalue=1, offvalue=0).grid(row=3,column=0, sticky=W)
SelvaNegra = Checkbutton(marcoPostres, text='SelvaNegra',font=Subtitle, onvalue=1, offvalue=0).grid(row=4,column=0, sticky=W)
Chocotorta = Checkbutton(marcoPostres, text='Chocotorta',font=Subtitle, onvalue=1, offvalue=0).grid(row=5,column=0, sticky=W)
Helado = Checkbutton(marcoPostres, text='Helado',font=Subtitle, onvalue=1, offvalue=0).grid(row=6,column=0, sticky=W)
Brownie = Checkbutton(marcoPostres, text='Brownie',font=Subtitle, onvalue=1, offvalue=0).grid(row=7,column=0, sticky=W)
Mousse = Checkbutton(marcoPostres, text='Mousse',font=Subtitle, onvalue=1, offvalue=0).grid(row=8,column=0, sticky=W)
EnsaladaFrutas = Checkbutton(marcoPostres, text='EnsaladaFrutas',font=Subtitle, onvalue=1, offvalue=0).grid(row=9,column=0, sticky=W)
#Campo para completar
textFlan = Entry(marcoPostres, font=Subtitle, bd=7, width=8, state=DISABLED).grid(row=0,column=1)
textDuraznosCrema = Entry(marcoPostres, font=Subtitle, bd=7, width=8, state=DISABLED).grid(row=1,column=1)
textFrutillasCrema = Entry(marcoPostres, font=Subtitle, bd=7, width=8, state=DISABLED).grid(row=2,column=1)
textLemonPie = Entry(marcoPostres, font=Subtitle, bd=7, width=8, state=DISABLED).grid(row=3,column=1)
textSelvaNegra = Entry(marcoPostres, font=Subtitle, bd=7, width=8, state=DISABLED).grid(row=4,column=1)
textChocotorta = Entry(marcoPostres, font=Subtitle, bd=7, width=8, state=DISABLED).grid(row=5,column=1)
textHelado = Entry(marcoPostres, font=Subtitle, bd=7, width=8, state=DISABLED).grid(row=6,column=1)
textBrownie = Entry(marcoPostres, font=Subtitle, bd=7, width=8, state=DISABLED).grid(row=7,column=1)
textMousse = Entry(marcoPostres, font=Subtitle, bd=7, width=8, state=DISABLED).grid(row=8,column=1)
textEnsaladaFrutas = Entry(marcoPostres, font=Subtitle, bd=7, width=8, state=DISABLED).grid(row=9,column=1)

#Etiquetas de total y entradas para los valores.
costoComida=Label(marcoCosto, text='Total en comidas', font=Subtitle, bd=10, bg='blue', fg='white').grid(row=0,column=0)
casillaCostoComida = Entry(marcoCosto, font=Subtitle, bd=10, width=14, state='readonly').grid(row=0,column=1, padx=5)
costoBebida=Label(marcoCosto, text='Total en bebidas', font=Subtitle, bd=10, width=14, bg='blue', fg='white').grid(row=1,column=0)
casillaCostoBebida = Entry(marcoCosto, font=Subtitle, bd=10, width=14, state='readonly').grid(row=1,column=1)
costoPostre=Label(marcoCosto, text='Total en postres', font=Subtitle, bd=10, bg='blue', fg='white').grid(row=2,column=0)
casillaCostoPostre = Entry(marcoCosto, font=Subtitle, bd=10, width=14, state='readonly').grid(row=2,column=1)

SubTotal=Label(marcoCosto, text='SubTotal', font=Subtitle, bd=10, bg='blue', fg='white').grid(row=0,column=2)
casillaSubTotal = Entry(marcoCosto, font=Subtitle, bd=10, width=14, state='readonly').grid(row=0,column=3, padx=41)
iVA=Label(marcoCosto, text='Imp. IVA', font=Subtitle, bd=10, width=14, bg='blue', fg='white').grid(row=1,column=2)
casillaiVA = Entry(marcoCosto, font=Subtitle, bd=10, width=14, bg='blue', fg='white', state='readonly').grid(row=1,column=3)
pagoTotal=Label(marcoCosto, text='Pago Total', font=Subtitle, bd=10, bg='blue', fg='white').grid(row=2,column=2)
casillaPagoTotal = Entry(marcoCosto, font=Subtitle, bd=10, width=14, state='readonly').grid(row=2,column=3)

#Calculadora
pantallacalculadora = Entry(marcoCalculadora, font=('arial',18,'bold'), width=33, bd=4).grid(row=0,column=0,columnspan=4)
boton7 = Button(marcoCalculadora, text=7, font=Subtitle, fg='white', bg='blue', bd=6, width=9).grid(row=1,column=0)
boton8 = Button(marcoCalculadora, text=8, font=Subtitle, fg='white', bg='blue', bd=6, width=9).grid(row=1,column=1)
boton9 = Button(marcoCalculadora, text=9, font=Subtitle, fg='white', bg='blue', bd=6, width=9).grid(row=1,column=2)
botonMas = Button(marcoCalculadora, text='+', font=Subtitle, fg='blue', bg='lightgray', bd=6, width=9).grid(row=1,column=3)

boton4 = Button(marcoCalculadora, text=4, font=Subtitle, fg='white', bg='blue', bd=6, width=9).grid(row=2,column=0)
boton5 = Button(marcoCalculadora, text=5, font=Subtitle, fg='white', bg='blue', bd=6, width=9).grid(row=2,column=1)
boton6 = Button(marcoCalculadora, text=6, font=Subtitle, fg='white', bg='blue', bd=6, width=9).grid(row=2,column=2)
botonMenos = Button(marcoCalculadora, text='-', font=Subtitle, fg='blue', bg='lightgray', bd=6, width=9).grid(row=2,column=3)

boton1 = Button(marcoCalculadora, text=1, font=Subtitle, fg='white', bg='blue', bd=6, width=9).grid(row=3,column=0)
boton2 = Button(marcoCalculadora, text=2, font=Subtitle, fg='white', bg='blue', bd=6, width=9).grid(row=3,column=1)
boton3 = Button(marcoCalculadora, text=3, font=Subtitle, fg='white', bg='blue', bd=6, width=9).grid(row=3,column=2)
botonPor = Button(marcoCalculadora, text='*', font=Subtitle, fg='blue', bg='lightgray', bd=6, width=9).grid(row=3,column=3)

boton0 = Button(marcoCalculadora, text=0, font=Subtitle, fg='white', bg='blue', bd=6, width=9).grid(row=4,column=0)
botonIgual = Button(marcoCalculadora, text='=', font=Subtitle, fg='blue', bg='lightgray', bd=6, width=9).grid(row=4,column=1)
botonBorar = Button(marcoCalculadora, text='C', font=Subtitle, fg='blue', bg='lightgray', bd=6, width=9).grid(row=4,column=2)
botonDivision = Button(marcoCalculadora, text='/', font=Subtitle, fg='blue', bg='lightgray', bd=6, width=9).grid(row=4,column=3)

#Recibo
textoRecibo = Text(marcoRecibo, font=('arial',12,'bold'),width=48, bd=3, height=12).grid(row=0,column=0)

#Ejecucion botones
botonTotal = Button(marcoBotones, text='Total', font=Subtitle,fg='white', bg='blue', bd=4, padx=5).grid(row=0,column=0)
botonRecibo = Button(marcoBotones, text='Recibo', font=Subtitle,fg='white', bg='blue', bd=4, padx=5).grid(row=0,column=1)
botonGuardar = Button(marcoBotones, text='Guardar', font=Subtitle,fg='white', bg='blue', bd=4, padx=5).grid(row=0,column=2)
botonEnviar = Button(marcoBotones, text='Enviar', font=Subtitle,fg='white', bg='blue', bd=4, padx=5).grid(row=0,column=3)
botonBorrar = Button(marcoBotones, text='Borrar', font=Subtitle,fg='white', bg='blue', bd=4, padx=5).grid(row=0,column=4)



ventana.mainloop()
